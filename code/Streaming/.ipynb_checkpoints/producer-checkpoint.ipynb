# %%
# !pip install confluent_kafka

# %%
from confluent_kafka import Producer
import json
import time
import random


conf = {
    'bootstrap.servers': 'pkc-56d1g.eastus.azure.confluent.cloud:9092',
    'security.protocol': 'SASL_SSL',
    'sasl.mechanisms': 'PLAIN',
    'sasl.username': 'JUKQQM4ZM632RECA',
    'sasl.password': 'UUkrPuSttgOC0U9lY3ZansNsKfN9fbxZPFwrGxudDrfv+knTD4rCwK+KdIzVPX0D',
}

# add topic_name here 
topic = 'mark_topic'

def generate_event(event_type):
    event = {
        "eventType": event_type,
        "customerId": str(random.randint(10000, 99999)),
        "productId": str(random.randint(1000, 1500)),
        "timestamp": time.strftime('%Y-%m-%dT%H:%M:%S'),https://drive.google.com/drive/folders/1vI26xDaXl4AoQnCo_pUFfhBk7BqwN33o
        "metadata": {}
    }
    
    if event_type == "productView":
        event["metadata"]["category"] = random.choice(["Electronics", "Clothing", "Home & Kitchen", "Books"])
        event["metadata"]["source"] = random.choice(["Advertisement", "Search", "Direct"])
    elif event_type == "addToCart":
        event["quantity"] = random.randint(1, 5)
    elif event_type == "purchase":
        event["quantity"] = random.randint(1, 5)
        event["totalAmount"] = round(random.uniform(10, 500), 2)
        event["paymentMethod"] = random.choice(["Credit Card", "Debit Card", "PayPal"])
    elif event_type == "recommendationClick":
        event["recommendedProductId"] = str(random.randint(1000, 9999))
        event["algorithm"] = random.choice(["collaborative_filtering", "content_based"])
    return event

producer = Producer(conf)

def send_event(event):
    try:
        producer.produce(topic, json.dumps(event))
        print("Event produced:", event)
    except Exception as e:
        print("Error:", e)

def main():
    while True:
        event_type = random.choice(["productView", "addToCart", "purchase", "recommendationClick"])
        event = generate_event(event_type)
        print(event)
        send_event(event)
        time.sleep(random.uniform(0.5, 2))

if __name__ == "__main__":
    main()
# Out:
# {'eventType': 'purchase', 'customerId': '59510', 'productId': '1282', 'timestamp': '2024-07-05T18:41:16', 'metadata': {}, 'quantity': 2, 'totalAmount': 448.97, 'paymentMethod': 'PayPal'}
# Event produced: {'eventType': 'purchase', 'customerId': '59510', 'productId': '1282', 'timestamp': '2024-07-05T18:41:16', 'metadata': {}, 'quantity': 2, 'totalAmount': 448.97, 'paymentMethod': 'PayPal'}
# {'eventType': 'addToCart', 'customerId': '19125', 'productId': '1369', 'timestamp': '2024-07-05T18:41:18', 'metadata': {}, 'quantity': 3}
# Event produced: {'eventType': 'addToCart', 'customerId': '19125', 'productId': '1369', 'timestamp': '2024-07-05T18:41:18', 'metadata': {}, 'quantity': 3}
# {'eventType': 'addToCart', 'customerId': '74885', 'productId': '1462', 'timestamp': '2024-07-05T18:41:19', 'metadata': {}, 'quantity': 2}
# Event produced: {'eventType': 'addToCart', 'customerId': '74885', 'productId': '1462', 'timestamp': '2024-07-05T18:41:19', 'metadata': {}, 'quantity': 2}
# {'eventType': 'addToCart', 'customerId': '46865', 'productId': '1287', 'timestamp': '2024-07-05T18:41:20', 'metadata': {}, 'quantity': 1}
# Event produced: {'eventType': 'addToCart', 'customerId': '46865', 'productId': '1287', 'timestamp': '2024-07-05T18:41:20', 'metadata': {}, 'quantity': 1}
# {'eventType': 'recommendationClick', 'customerId': '71227', 'productId': '1481', 'timestamp': '2024-07-05T18:41:21', 'metadata': {}, 'recommendedProductId': '3688', 'algorithm': 'collaborative_filtering'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '71227', 'productId': '1481', 'timestamp': '2024-07-05T18:41:21', 'metadata': {}, 'recommendedProductId': '3688', 'algorithm': 'collaborative_filtering'}
# {'eventType': 'recommendationClick', 'customerId': '50773', 'productId': '1154', 'timestamp': '2024-07-05T18:41:22', 'metadata': {}, 'recommendedProductId': '8898', 'algorithm': 'collaborative_filtering'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '50773', 'productId': '1154', 'timestamp': '2024-07-05T18:41:22', 'metadata': {}, 'recommendedProductId': '8898', 'algorithm': 'collaborative_filtering'}
# {'eventType': 'recommendationClick', 'customerId':
 'metadata': {'category': 'Clothing', 'source': 'Advertisement'}}
# {'eventType': 'recommendationClick', 'customerId': '45379', 'productId': '1260', 'timestamp': '2024-07-05T18:41:56', 'metadata': {}, 'recommendedProductId': '1950', 'algorithm': 'content_based'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '45379', 'productId': '1260', 'timestamp': '2024-07-05T18:41:56', 'metadata': {}, 'recommendedProductId': '1950', 'algorithm': 'content_based'}
# {'eventType': 'addToCart', 'customerId': '98364', 'productId': '1394', 'timestamp': '2024-07-05T18:41:58', 'metadata': {}, 'quantity': 3}
# Event produced: {'eventType': 'addToCart', 'customerId': '98364', 'productId': '1394', 'timestamp': '2024-07-05T18:41:58', 'metadata': {}, 'quantity': 3}
# {'eventType': 'productView', 'customerId': '40128', 'productId': '1117', 'timestamp': '2024-07-05T18:41:59', 'metadata': {'category': 'Home & Kitchen', 'source': 'Advertisement'}}
# Event produced: {'eventType': 'productView', 'customerId': '40128', 'productId': '1117', 'timestamp': '2024-07-05T18:41:59', 'metadata': {'category': 'Home & Kitchen', 'source': 'Advertisement'}}
# {'eventType': 'productView', 'customerId': '90246', 'productId': '1266', 'timestamp': '2024-07-05T18:42:00', 'metadata': {'category': 'Home & Kitchen', 'source': 'Direct'}}
# Event produced: {'eventType': 'productView', 'customerId': '90246', 'productId': '1266', 'timestamp': '2024-07-05T18:42:00', 'metadata': {'category': 'Home & Kitchen', 'source': 'Direct'}}
# {'eventType': 'addToCart', 'customerId': '57685', 'productId': '1333', 'timestamp': '2024-07-05T18:42:01', 'metadata': {}, 'quantity': 4}
# Event produced: {'eventType': 'addToCart', 'customerId': '57685', 'productId': '1333', 'timestamp': '2024-07-05T18:42:01', 'metadata': {}, 'quantity': 4}
# {'eventType': 'purchase', 'customerId': '50108', 'productId': '1158', 'timestamp': '2024-07-05T18:42:02', 'metadata': {}, 'quantity': 1, 'totalAmount': 352.17, 'paymentMethod': 'PayPal'}
# Event produced: {'eventType': 'purchase', 'customerId': '50108', 'productId': '1158', 'timestamp': '2024-07-05T18:42:02', 'metadata': {}, 'quantity': 1, 'totalAmount': 352.17, 'paymentMethod': 'PayPal'}
# {'eventType': 'productView', 'customerId': '66502', 'productId': '1055', 'timestamp': '2024-07-05T18:42:02', 'metadata': {'category': 'Clothing', 'source': 'Advertisement'}}
# Event produced: {'eventType': 'productView', 'customerId': '66502', 'productId': '1055', 'timestamp': '2024-07-05T18:42:02', 'metadata': {'category': 'Clothing', 'source': 'Advertisement'}}
# {'eventType': 'recommendationClick', 'customerId': '60001', 'productId': '1308', 'timestamp': '2024-07-05T18:42:04', 'metadata': {}, 'recommendedProductId': '1686', 'algorithm': 'collaborative_filtering'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '60001', 'productId': '1308', 'timestamp': '2024-07-05T18:42:04', 'metadata': {}, 'recommendedProductId': '1686', 'algorithm': 'collaborative_filtering'}
# {'eventType': 'recommendationClick', 'customerId': '34149', 'productId': '1199', 'timestamp': '2024-07-05T18:42:06', 'metadata': {}, 'recommendedProductId': '5723', 'algorithm': 'collaborative_filtering'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '34149', 'productId': '1199', 'timestamp': '2024-07-05T18:42:06', 'metadata': {}, 'recommendedProductId': '5723', 'algorithm': 'collaborative_filtering'}
# {'eventType': 'recommendationClick', 'customerId': '14644', 'productId': '1129', 'timestamp': '2024-07-05T18:42:08', 'metadata': {}, 'recommendedProductId': '5332', 'algorithm': 'collaborative_filtering'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '14644', 'productId': '1129', 'timestamp': '2024-07-05T18:42:08', 'metadata': {}, 'recommendedProductId': '5332', 'algorithm': 'collaborative_filtering'}
# {'eventType': 'addToCart', 'customerId': '38340', 'productId': '1014', 'timestamp': '2024-07-05T18:42:08', 'metadata': {}, 'quantity': 3}
# Event produced: {'eventType': 'addToCart', 'customerId': '38340', 'productId': '1014', 'timestamp': '2024-07-05T18:42:08', 'metadata': {}, 'quantity': 3}
# {'eventType': 'purchase', 'customerId': '61192', 'productId': '1092', 'timestamp': '2024-07-05T18:42:09', 'metadata': {}, 'quantity': 5, 'totalAmount': 141.28, 'paymentMethod': 'PayPal'}
# Event produced: {'eventType': 'purchase', 'customerId': '61192', 'productId': '1092', 'timestamp': '2024-07-05T18:42:09', 'metadata': {}, 'quantity': 5, 'totalAmount': 141.28, 'paymentMethod': 'PayPal'}
# {'eventType': 'addToCart', 'customerId': '17495', 'productId': '1141', 'timestamp': '2024-07-05T18:42:11', 'metadata': {}, 'quantity': 1}
# Event produced: {'eventType': 'addToCart', 'customerId': '17495', 'productId': '1141', 'timestamp': '2024-07-05T18:42:11', 'metadata': {}, 'quantity': 1}
# {'eventType': 'purchase', 'customerId': '63426', 'productId': '1281', 'timestamp': '2024-07-05T18:42:13', 'metadata': {}, 'quantity': 1, 'totalAmount': 310.31, 'paymentMethod': 'Credit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '63426', 'productId': '1281', 'timestamp': '2024-07-05T18:42:13', 'metadata': {}, 'quantity': 1, 'totalAmount': 310.31, 'paymentMethod': 'Credit Card'}
# {'eventType': 'recommendationClick', 'customerId': '61617', 'productId': '1152', 'timestamp': '2024-07-05T18:42:15', 'metadata': {}, 'recommendedProductId': '7321', 'algorithm': 'collaborative_filtering'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '61617', 'productId': '1152', 'timestamp': '2024-07-05T18:42:15', 'metadata': {}, 'recommendedProductId': '7321', 'algorithm': 'collaborative_filtering'}
# {'eventType': 'recommendationClick', 'customerId': '33776', 'productId': '1455', 'timestamp': '2024-07-05T18:42:16', 'metadata': {}, 'recommendedProductId': '1586', 'algorithm': 'content_based'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '33776', 'productId': '1455', 'timestamp': '2024-07-05T18:42:16', 'metadata': {}, 'recommendedProductId': '1586', 'algorithm': 'content_based'}
# {'eventType': 'addToCart', 'customerId': '40873', 'productId': '1278', 'timestamp': '2024-07-05T18:42:18', 'metadata': {}, 'quantity': 5}
# Event produced: {'eventType': 'addToCart', 'customerId': '40873', 'productId': '1278', 'timestamp': '2024-07-05T18:42:18', 'metadata': {}, 'quantity': 5}
# {'eventType': 'purchase', 'customerId': '72857', 'productId': '1025', 'timestamp': '2024-07-05T18:42:19', 'metadata': {}, 'quantity': 1, 'totalAmount': 58.31, 'paymentMethod': 'Credit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '72857', 'productId': '1025', 'timestamp': '2024-07-05T18:42:19', 'metadata': {}, 'quantity': 1, 'totalAmount': 58.31, 'paymentMethod': 'Credit Card'}
# {'eventType': 'productView', 'customerId': '51533', 'productId': '1131', 'timestamp': '2024-07-05T18:42:20', 'metadata': {'category': 'Home & Kitchen', 'source': 'Direct'}}
# Event produced: {'eventType': 'productView', 'customerId': '51533', 'productId': '1131', 'timestamp': '2024-07-05T18:42:20', 'metadata': {'category': 'Home & Kitchen', 'source': 'Direct'}}
# {'eventType': 'purchase', 'customerId': '38044', 'productId': '1152', 'timestamp': '2024-07-05T18:42:22', 'metadata': {}, 'quantity': 2, 'totalAmount': 350.59, 'paymentMethod': 'Credit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '38044', 'productId': '1152', 'timestamp': '2024-07-05T18:42:22', 'metadata': {}, 'quantity': 2, 'totalAmount': 350.59, 'paymentMethod': 'Credit Card'}
# {'eventType': 'addToCart', 'customerId': '79307', 'productId': '1019', 'timestamp': '2024-07-05T18:42:23', 'metadata': {}, 'quantity': 1}
# Event produced: {'eventType': 'addToCart', 'customerId': '79307', 'productId': '1019', 'timestamp': '2024-07-05T18:42:23', 'metadata': {}, 'quantity': 1}
# {'eventType': 'recommendationClick', 'customerId': '95378', 'productId': '1004', 'timestamp': '2024-07-05T18:42:24', 'metadata': {}, 'recommendedProductId': '3208', 'algorithm': 'content_based'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '95378', 'productId': '1004', 'timestamp': '2024-07-05T18:42:24', 'metadata': {}, 'recommendedProductId': '3208', 'algorithm': 'content_based'}
# {'eventType': 'purchase', 'customerId': '65431', 'productId': '1011', 'timestamp': '2024-07-05T18:42:25', 'metadata': {}, 'quantity': 5, 'totalAmount': 128.89, 'paymentMethod': 'Credit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '65431', 'productId': '1011', 'timestamp': '2024-07-05T18:42:25', 'metadata': {}, 'quantity': 5, 'totalAmount': 128.89, 'paymentMethod': 'Credit Card'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-6bcbe2840492> in <module>
#      57
#      58 if __name__ == "__main__":
# ---> 59     main()
#
# <ipython-input-1-6bcbe2840492> in main()
#      54         print(event)
#      55         send_event(event)
# ---> 56         time.sleep(random.uniform(0.5, 2))
#      57
#      58 if __name__ == "__main__":
#
# KeyboardInterrupt:
