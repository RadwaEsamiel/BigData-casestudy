# %%
# !pip install confluent_kafka

# %%
from confluent_kafka import Producer
import json
import time
import random


conf = {
    'bootstrap.servers': 'pkc-56d1g.eastus.azure.confluent.cloud:9092',
    'security.protocol': 'SASL_SSL',
    'sasl.mechanisms': 'PLAIN',
    'sasl.username': 'JUKQQM4ZM632RECA',
    'sasl.password': 'UUkrPuSttgOC0U9lY3ZansNsKfN9fbxZPFwrGxudDrfv+knTD4rCwK+KdIzVPX0D',
}

# add topic_name here 
topic = 'mark_topic'

def generate_event(event_type):
    event = {
        "eventType": event_type,
        "customerId": str(random.randint(10000, 99999)),
        "productId": str(random.randint(1000, 1500)),
        "timestamp": time.strftime('%Y-%m-%dT%H:%M:%S'),
        "metadata": {}
    }
    
    if event_type == "productView":
        event["metadata"]["category"] = random.choice(["Electronics", "Clothing", "Home & Kitchen", "Books"])
        event["metadata"]["source"] = random.choice(["Advertisement", "Search", "Direct"])
    elif event_type == "addToCart":
        event["quantity"] = random.randint(1, 5)
    elif event_type == "purchase":
        event["quantity"] = random.randint(1, 5)
        event["totalAmount"] = round(random.uniform(10, 500), 2)
        event["paymentMethod"] = random.choice(["Credit Card", "Debit Card", "PayPal"])
    elif event_type == "recommendationClick":
        event["recommendedProductId"] = str(random.randint(1000, 9999))
        event["algorithm"] = random.choice(["collaborative_filtering", "content_based"])
    return event

producer = Producer(conf)

def send_event(event):
    try:
        producer.produce(topic, json.dumps(event))
        print("Event produced:", event)
    except Exception as e:
        print("Error:", e)

def main():
    while True:
        event_type = random.choice(["productView", "addToCart", "purchase", "recommendationClick"])
        event = generate_event(event_type)
        print(event)
        send_event(event)
        time.sleep(random.uniform(0.5, 2))

if __name__ == "__main__":
    main()
# Out:
# {'eventType': 'productView', 'customerId': '42943', 'productId': '1004', 'timestamp': '2024-07-06T06:55:04', 'metadata': {'category': 'Clothing', 'source': 'Advertisement'}}
# Event produced: {'eventType': 'productView', 'customerId': '42943', 'productId': '1004', 'timestamp': '2024-07-06T06:55:04', 'metadata': {'category': 'Clothing', 'source': 'Advertisement'}}
# {'eventType': 'recommendationClick', 'customerId': '50904', 'productId': '1428', 'timestamp': '2024-07-06T06:55:06', 'metadata': {}, 'recommendedProductId': '3156', 'algorithm': 'content_based'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '50904', 'productId': '1428', 'timestamp': '2024-07-06T06:55:06', 'metadata': {}, 'recommendedProductId': '3156', 'algorithm': 'content_based'}
# {'eventType': 'addToCart', 'customerId': '94829', 'productId': '1314', 'timestamp': '2024-07-06T06:55:07', 'metadata': {}, 'quantity': 4}
# Event produced: {'eventType': 'addToCart', 'customerId': '94829', 'productId': '1314', 'timestamp': '2024-07-06T06:55:07', 'metadata': {}, 'quantity': 4}
# {'eventType': 'recommendationClick', 'customerId': '77552', 'productId': '1164', 'timestamp': '2024-07-06T06:55:09', 'metadata': {}, 'recommendedProductId': '8087', 'algorithm': 'collaborative_filtering'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '77552', 'productId': '1164', 'timestamp': '2024-07-06T06:55:09', 'metadata': {}, 'recommendedProductId': '8087', 'algorithm': 'collaborative_filtering'}
# {'eventType': 'recommendationClick', 'customerId': '64494', 'productId': '1391', 'timestamp': '2024-07-06T06:55:10', 'metadata': {}, 'recommendedProductId': '9820', 'algorithm': 'content_based'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '64494', 'productId': '1391', 'timestamp': '2024-07-06T06:55:10', 'metadata': {}, 'recommendedProductId': '9820', 'algorithm': 'content_based'}
# {'eventType': 'purchase', 'customerId': '26256', 'productId': '1013', 'timestamp': '2024-07-06T06:55:11', 'metadata': {}, 'quantity': 1, 'totalAmount': 491.86, 'paymentMethod': 'Debit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '26256', 'productId': '1013', 'timestamp': '2024-07-06T06:55:11', 'metadata': {}, 'quantity': 1, 'totalAmount': 491.86, 'paymentMethod': 'Debit Card'}
# {'eventType': 'productView', 'customerId': '53022', 'productId': '1266', 'timestamp': '2024-07-06T06:55:12', 'metadata': {'category': 'Clothing', 'source': 'Search'}}
# Event produced: {'eventType': 'productView', 'customerId': '53022', 'productId': '1266', 'timestamp': '2024-07-06T06:55:12', 'metadata': {'category': 'Clothing', 'source': 'Search'}}
# {'eventType': 'recommendationClick', 'customerId': '64078', 'productId': '1057', 'timestamp': '2024-07-06T06:55:13', 'metadata': {}, 'recommendedProductId': '3220', 'algorithm': 'content_based'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '64078', 'productId': '1057', 'timestamp': '2024-07-06T06:55:13', 'metadata': {}, 'recommendedProductId': '3220', 'algorithm': 'content_based'}
# {'eventType': 'purchase', 'customerId': '54843', 'productId': '1370', 'timestamp': '2024-07-06T06:55:15', 'metadata': {}, 'quantity': 3, 'totalAmount': 493.27, 'paymentMethod': 'Credit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '54843', 'productId': '1370', 'timestamp': '2024-07-06T06:55:15', 'metadata': {}, 'quantity': 3, 'totalAmount': 493.27, 'paymentMethod': 'Credit Card'}
# {'eventType': 'recommendationClick', 'customerId': '19357', 'productId': '1139', 'timestamp': '2024-07-06T06:55:16', 'metadata': {}, 'recommendedProductId': '9637', 'algorithm': 'content_based'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '19357', 'productId': '1139', 'timestamp': '2024-07-06T06:55:16', 'metadata': {}, 'recommendedProductId': '9637', 'algorithm': 'content_based'}
# {'eventType': 'addToCart', 'customerId': '21584', 'productId': '1225', 'timestamp': '2024-07-06T06:55:18', 'metadata': {}, 'quantity': 3}
# Event produced: {'eventType': 'addToCart', 'customerId': '21584', 'productId': '1225', 'timestamp': '2024-07-06T06:55:18', 'metadata': {}, 'quantity': 3}
# {'eventType': 'purchase', 'customerId': '16681', 'productId': '1363', 'timestamp': '2024-07-06T06:55:18', 'metadata': {}, 'quantity': 4, 'totalAmount': 108.23, 'paymentMethod': 'Debit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '16681', 'productId': '1363', 'timestamp': '2024-07-06T06:55:18', 'metadata': {}, 'quantity': 4, 'totalAmount': 108.23, 'paymentMethod': 'Debit Card'}
# {'eventType': 'productView', 'customerId': '34653', 'productId': '1437', 'timestamp': '2024-07-06T06:55:19', 'metadata': {'category': 'Electronics', 'source': 'Search'}}
# Event produced: {'eventType': 'productView', 'customerId': '34653', 'productId': '1437', 'timestamp': '2024-07-06T06:55:19', 'metadata': {'category': 'Electronics', 'source': 'Search'}}
# {'eventType': 'purchase', 'customerId': '15574', 'productId': '1312', 'timestamp': '2024-07-06T06:55:20', 'metadata': {}, 'quantity': 3, 'totalAmount': 445.42, 'paymentMethod': 'Credit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '15574', 'productId': '1312', 'timestamp': '2024-07-06T06:55:20', 'metadata': {}, 'quantity': 3, 'totalAmount': 445.42, 'paymentMethod': 'Credit Card'}
# {'eventType': 'recommendationClick', 'customerId': '84825', 'productId': '1080', 'timestamp': '2024-07-06T06:55:22', 'metadata': {}, 'recommendedProductId': '1054', 'algorithm': 'content_based'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '84825', 'productId': '1080', 'timestamp': '2024-07-06T06:55:22', 'metadata': {}, 'recommendedProductId': '1054', 'algorithm': 'content_based'}
# {'eventType': 'addToCart', 'customerId': '76682', 'productId': '1148', 'timestamp': '2024-07-06T06:55:22', 'metadata': {}, 'quantity': 3}
# Event produced: {'eventType': 'addToCart', 'customerId': '76682', 'productId': '1148', 'timestamp': '2024-07-06T06:55:22', 'metadata': {}, 'quantity': 3}
# {'eventType': 'productView', 'customerId': '91193', 'productId': '1399', 'timestamp': '2024-07-06T06:55:24', 'metadata': {'category': 'Books', 'source': 'Advertisement'}}
# Event produced: {'eventType': 'productView', 'customerId': '91193', 'productId': '1399', 'timestamp': '2024-07-06T06:55:24', 'metadata': {'category': 'Books', 'source': 'Advertisement'}}
# {'eventType': 'addToCart', 'customerId': '49141', 'productId': '1129', 'timestamp': '2024-07-06T06:55:25', 'metadata': {}, 'quantity': 1}
# Event produced: {'eventType': 'addToCart', 'customerId': '49141', 'productId': '1129', 'timestamp': '2024-07-06T06:55:25', 'metadata': {}, 'quantity': 1}
# {'eventType': 'recommendationClick', 'customerId': '90881', 'productId': '1063', 'timestamp': '2024-07-06T06:55:26', 'metadata': {}, 'recommendedProductId': '8542', 'algorithm': 'collaborative_filtering'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '90881', 'productId': '1063', 'timestamp': '2024-07-06T06:55:26', 'metadata': {}, 'recommendedProductId': '8542', 'algorithm': 'collaborative_filtering'}
# {'eventType': 'purchase', 'customerId': '38256', 'productId': '1352', 'timestamp': '2024-07-06T06:55:28', 'metadata': {}, 'quantity': 4, 'totalAmount': 442.24, 'paymentMethod': 'Credit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '38256', 'productId': '1352', 'timestamp': '2024-07-06T06:55:28', 'metadata': {}, 'quantity': 4, 'totalAmount': 442.24, 'paymentMethod': 'Credit Card'}
# {'eventType': 'addToCart', 'customerId': '66456', 'productId': '1047', 'timestamp': '2024-07-06T06:55:30', 'metadata': {}, 'quantity': 1}
# Event produced: {'eventType': 'addToCart', 'customerId': '66456', 'productId': '1047', 'timestamp': '2024-07-06T06:55:30', 'metadata': {}, 'quantity': 1}
# {'eventType': 'purchase', 'customerId': '34139', 'productId': '1296', 'timestamp': '2024-07-06T06:55:31', 'metadata': {}, 'quantity': 4, 'totalAmount': 279.83, 'paymentMethod': 'Debit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '34139', 'productId': '1296', 'timestamp': '2024-07-06T06:55:31', 'metadata': {}, 'quantity': 4, 'totalAmount': 279.83, 'paymentMethod': 'Debit Card'}
# {'eventType': 'addToCart', 'customerId': '94660', 'productId': '1479', 'timestamp': '2024-07-06T06:55:32', 'metadata': {}, 'quantity': 1}
# Event produced: {'eventType': 'addToCart', 'customerId': '94660', 'productId': '1479', 'timestamp': '2024-07-06T06:55:32', 'metadata': {}, 'quantity': 1}
# {'eventType': 'productView', 'customerId': '48947', 'productId': '1372', 'timestamp': '2024-07-06T06:55:33', 'metadata': {'category': 'Home & Kitchen', 'source': 'Search'}}
# Event produced: {'eventType': 'productView', 'customerId': '48947', 'productId': '1372', 'timestamp': '2024-07-06T06:55:33', 'metadata': {'category': 'Home & Kitchen', 'source': 'Search'}}
# {'eventType': 'purchase', 'customerId': '66042', 'productId': '1485', 'timestamp': '2024-07-06T06:55:33', 'metadata': {}, 'quantity': 4, 'totalAmount': 275.93, 'paymentMethod': 'PayPal'}
# Event produced: {'eventType': 'purchase', 'customerId': '66042', 'productId': '1485', 'timestamp': '2024-07-06T06:55:33', 'metadata': {}, 'quantity': 4, 'totalAmount': 275.93, 'paymentMethod': 'PayPal'}
# {'eventType': 'recommendationClick', 'customerId': '18204', 'productId': '1359', 'timestamp': '2024-07-06T06:55:34', 'metadata': {}, 'recommendedProductId': '8331', 'algorithm': 'collaborative_filtering'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '18204', 'productId': '1359', 'timestamp': '2024-07-06T06:55:34', 'metadata': {}, 'recommendedProductId': '8331', 'algorithm': 'collaborative_filtering'}
# {'eventType': 'purchase', 'customerId': '53692', 'productId': '1226', 'timestamp': '2024-07-06T06:55:35', 'metadata': {}, 'quantity': 5, 'totalAmount': 258.14, 'paymentMethod': 'PayPal'}
# Event produced: {'eventType': 'purchase', 'customerId': '53692', 'productId': '1226', 'timestamp': '2024-07-06T06:55:35', 'metadata': {}, 'quantity': 5, 'totalAmount': 258.14, 'paymentMethod': 'PayPal'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6bcbe2840492> in <module>
#      57
#      58 if __name__ == "__main__":
# ---> 59     main()
#
# <ipython-input-2-6bcbe2840492> in main()
#      54         print(event)
#      55         send_event(event)
# ---> 56         time.sleep(random.uniform(0.5, 2))
#      57
#      58 if __name__ == "__main__":
#
# KeyboardInterrupt:
